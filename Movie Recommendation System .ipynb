# %% [markdown]
# # Plot Description Movie Recommendation System

# %% [markdown]
# Dataset:https://www.kaggle.com/datasets/tmdb/tmdb-movie-metadata

# %%
import pandas as pd 
import numpy as np 
df=pd.read_csv(r"C:\Users\mapze\OneDrive\Documents\Python Scripts\Machine Learning\tmdb_5000_movies.csv")
df2=pd.read_csv(r"C:\Users\mapze\OneDrive\Documents\Python Scripts\Machine Learning\tmdb_5000_credits.csv")

# %%
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
df2
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4798      9367                               El Mariachi
# 4799     72766                                 Newlyweds
# 4800    231617                 Signed, Sealed, Delivered
# 4801    126186                          Shanghai Calling
# 4802     25975                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# ...

# %%
df2.columns = ['id','title','cast','crew']

# %%
df2
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# 3     [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# ...

# %% [markdown]
# ## Merging Dataframes

# %%
df= df.merge(df2,on='id')

# %%
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
df=df.drop('title_y',axis=1)

# %%
df['title']=df['title_x']

# %%
df=df.drop('title_x',axis=1)

# %%
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# ## The 50 highest rated movies that have at least 1000 votes

# %%
High_rating= df.loc[df['vote_count'] >= 1000]

# %%
High_rating=High_rating.sort_values('vote_average',ascending=False)

# %%
High_rating=High_rating[['title','vote_average','vote_count']][1:50]

# %%
High_rating
# Out:
#                                                   title  vote_average  \
# 3337                                      The Godfather           8.4
# 3232                                       Pulp Fiction           8.3
# 2294                                      Spirited Away           8.3
# 2731                             The Godfather: Part II           8.3
# 1818                                   Schindler's List           8.3
# 3865                                           Whiplash           8.3
# 662                                          Fight Club           8.3
# 1987                               Howl's Moving Castle           8.2
# 3719                    One Flew Over the Cuckoo's Nest           8.2
# 65                                      The Dark Knight           8.2
# 3057                                 American History X           8.2
# 1663                        Once Upon a Time in America           8.2
# ...

# %% [markdown]
# ## Top 10 Movies by Popularity

# %%
import matplotlib.pyplot as plt
popularity= df.sort_values('popularity', ascending=False)
plt.figure(figsize=(12,4))
plt.barh(popularity['title'].head(10),popularity['popularity'].head(10), align='center',
        color='red')
plt.xlabel("Popularity")
plt.title("Popular Movies")
plt.show()

# %%
#Plot description movie recommender
df['overview'].head(5)
# Out:
# 0    In the 22nd century, a paraplegic Marine is di...
# 1    Captain Barbossa, long believed to be dead, ha...
# 2    A cryptic message from Bond’s past sends him o...
# 3    Following the death of District Attorney Harve...
# 4    John Carter is a war-weary, former military ca...
# Name: overview, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfid = TfidfVectorizer(stop_words='english')

# %%
df['overview'] = df['overview'].fillna('')

# %%
tfid_matrix = tfid.fit_transform(df['overview'])

# %%
tfid_matrix.shape
# Out:
# (4803, 20978)

# %%
from sklearn.metrics.pairwise import linear_kernel

# %%
sim = linear_kernel(tfid_matrix, tfid_matrix)

# %%
indices = pd.Series(df.index, index=df['title']).drop_duplicates()

# %% [markdown]
# ## Movie Recommendation Function

# %%
#movie title as input and outputs most similar movies
def recommendations(title, cosine_sim=sim):
    # index of the movie that matches the title
    idx = indices[title]

    # get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(sim[idx]))

    # sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores,key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:20]

    #Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 20 similar movies
    return df['title'].iloc[movie_indices]

# %% [markdown]
# ## Input movie title in function and get the 20 most similiar movies

# %%
recommendations('The Dark Knight Rises')
# Out:
# 65                              The Dark Knight
# 299                              Batman Forever
# 428                              Batman Returns
# 1359                                     Batman
# 3854    Batman: The Dark Knight Returns, Part 2
# 119                               Batman Begins
# 2507                                  Slow Burn
# 9            Batman v Superman: Dawn of Justice
# 1181                                        JFK
# 210                              Batman & Robin
# 879                         Law Abiding Citizen
# 2193                       Secret in Their Eyes
# 1398                                  Max Payne
# 2416                                    Beastly
# 1068       The Hitchhiker's Guide to the Galaxy
# 979                         Free State of Jones
# 1202                               Legal Eagles
# 790                             American Sniper
# 2274                                   Survivor
# Name: title, dtype: object

# %%
recommendations('The Avengers')
# Out:
# 7                Avengers: Age of Ultron
# 3144                             Plastic
# 1715                             Timecop
# 4124                  This Thing of Ours
# 3311               Thank You for Smoking
# 3033                       The Corruptor
# 588      Wall Street: Money Never Sleeps
# 2136          Team America: World Police
# 1468                        The Fountain
# 1286                         Snowpiercer
# 256                            Allegiant
# 1197                   Horrible Bosses 2
# 1161                  The Social Network
# 2433    Superman IV: The Quest for Peace
# 2646                      Silent Trigger
# 227                       Knight and Day
# 2097                   Are We There Yet?
# 602            Ballistic: Ecks vs. Sever
# 4620                Fighting Tommy Riley
# Name: title, dtype: object

# %%
recommendations('Star Wars')
# Out:
# 1990                         The Empire Strikes Back
# 1490                              Return of the Jedi
# 833                                    Shanghai Noon
# 1290                        Baahubali: The Beginning
# 2864                                       Arbitrage
# 2556                              The Princess Bride
# 410                                    Mirror Mirror
# 2929                    History of the World: Part I
# 1045        The Princess Diaries 2: Royal Engagement
# 2232                                     Topsy-Turvy
# 50               Prince of Persia: The Sands of Time
# 229     Star Wars: Episode III - Revenge of the Sith
# 3203          Ultramarines: A Warhammer 40,000 Movie
# 3652                                          Decoys
# 627                                  The Last Legion
# 4574                                        Roadside
# 3191                        The Legend of Suriyothai
# 3195                               Princess Kaiulani
# ...
